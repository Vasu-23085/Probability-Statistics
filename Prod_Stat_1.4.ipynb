# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasu-23085/Probability-Statistics/blob/main/Prod_Stat_1.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

marks = [
42,55,67,73,59,48,62,71,65,58,
74,68,55,63,77,81,69,54,60,72,
66,57,64,70,55,78,61,75,56,67,
52,59,63,71,62,68,73,65,58,60,
76,69,64,57,74,80,66,61,53,72
]

bins = [40,50,60,70,80,90]

plt.figure(figsize=(8,5))

plt.hist(
 marks,
 bins=bins,
 color = 'blue',
 edgecolor='black'
)

plt.title("Histogram of Students' Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.grid(axis='y')
plt.show()
